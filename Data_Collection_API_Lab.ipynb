# %%
import requests
import pandas as pd
import numpy as np

# %%
# API endpoint for the SpaceX launch data
spacex_url = "https://api.spacexdata.com/v4/launches"

# Get data from the API
response = requests.get(spacex_url)

# Check response
print(response.status_code)

# Convert response to JSON
data = response.json()

# Convert JSON to DataFrame
data_falcon9 = pd.json_normalize(data)

# Display first 5 rows
data_falcon9.head()
# Out:
# 200
#        static_fire_date_utc  static_fire_date_unix    net  window  \
# 0  2006-03-17T00:00:00.000Z           1.142554e+09  False     0.0
# 1                      None                    NaN  False     0.0
# 2                      None                    NaN  False     0.0
# 3  2008-09-20T00:00:00.000Z           1.221869e+09  False     0.0
# 4                      None                    NaN  False     0.0
#
#                      rocket success  \
# 0  5e9d0d95eda69955f709d1eb   False
# 1  5e9d0d95eda69955f709d1eb   False
# 2  5e9d0d95eda69955f709d1eb   False
# 3  5e9d0d95eda69955f709d1eb    True
# 4  5e9d0d95eda69955f709d1eb    True
#
#                                             failures  \
# 0  [{'time': 33, 'altitude': None, 'reason': 'mer...
# 1  [{'time': 301, 'altitude': 289, 'reason': 'har...
# 2  [{'time': 140, 'altitude': 35, 'reason': 'resi...
# 3                                                 []
# 4                                                 []
#
# ...

# %%
# Calculate the mean of PayloadMass column
payload_mean = data_falcon9['payloads'].apply(lambda x: len(x) if isinstance(x, list) else np.nan).mean()

# Replace missing values (just an example, modify based on actual column)
data_falcon9['PayloadMass'] = data_falcon9['payloads'].apply(lambda x: len(x) if isinstance(x, list) else payload_mean)

# Save to CSV
data_falcon9.to_csv('dataset_part_1.csv', index=False)

# %%
columns = ['name', 'date_utc', 'rocket', 'payloads', 'launchpad', 'cores', 'success', 'details']
data_falcon9 = data_falcon9[columns]
data_falcon9.head()
# Out:
#           name                  date_utc                    rocket  \
# 0    FalconSat  2006-03-24T22:30:00.000Z  5e9d0d95eda69955f709d1eb
# 1      DemoSat  2007-03-21T01:10:00.000Z  5e9d0d95eda69955f709d1eb
# 2  Trailblazer  2008-08-03T03:34:00.000Z  5e9d0d95eda69955f709d1eb
# 3       RatSat  2008-09-28T23:15:00.000Z  5e9d0d95eda69955f709d1eb
# 4     RazakSat  2009-07-13T03:35:00.000Z  5e9d0d95eda69955f709d1eb
#
#                                             payloads  \
# 0                         [5eb0e4b5b6c3bb0006eeb1e1]
# 1                         [5eb0e4b6b6c3bb0006eeb1e2]
# 2  [5eb0e4b6b6c3bb0006eeb1e3, 5eb0e4b6b6c3bb0006e...
# 3                         [5eb0e4b7b6c3bb0006eeb1e5]
# 4                         [5eb0e4b7b6c3bb0006eeb1e6]
#
#                   launchpad  \
# 0  5e9e4502f5090995de566f86
# 1  5e9e4502f5090995de566f86
# 2  5e9e4502f5090995de566f86
# 3  5e9e4502f5090995de566f86
# 4  5e9e4502f5090995de566f86
#
# ...

# %%
# This will just count how many payloads were listed (as an approximation)
data_falcon9['PayloadMass'] = data_falcon9['payloads'].apply(lambda x: len(x) if isinstance(x, list) else np.nan)

# Now fill missing values with mean
payload_mean = data_falcon9['PayloadMass'].mean()
data_falcon9['PayloadMass'].replace(np.nan, payload_mean, inplace=True)

# %%
data_falcon9.to_csv('dataset_part_1.csv', index=False)
